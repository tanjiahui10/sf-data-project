# %% [markdown]
# # SF Data Project

# %%
import pandas as pd 
import geopandas as gpd
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-94-cc1d71a2fe69> in <module>
#       1 import pandas as pd
# ----> 2 import geopandas as gpd
#       3 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
import requests

# %%
import csv

# %%
import os
data_dir = os.environ['DATA_DIR']
waste_fp = os.path.join(data_dir, 'processed', 'human_animal_waste_311.csv')
with open(waste_fp,'r') as source_file:
    text = source_file.read()

# %%
df = pd.read_csv(waste_fp) #reads csv file

# %%
df.head()

# %%
pd.isnull(df).any() #detects missing value for array and indicate it

# %%
df['year'] = pd.DatetimeIndex(df['Opened']).year #finds the date part within object

# %%
df.head()

# %%
waste_by_years = df.groupby('year').count() #returns the number of occurrences

# %%
waste_by_years.sort_values('year').reset_index()

# %%
# %matplotlib inline

# %%
by_years = waste_by_years.sort_values('year').reset_index()

# %%
by_years.head()

# %%
by_years.plot(kind = 'scatter', x='year', y='Opened') #plots the graph

# %%
by_years.head(13)

# %%
by_years[1:12] #lists the 10 years that we are looking at
# Out:
#     year  CaseID  Opened  Closed  Updated  Status  StatusNotes  \
# 1   2009    5771    5771    5771     5771    5771         5769
# 2   2010    5852    5852    5852     5852    5852         5852
# 3   2011    5693    5693    5690     5693    5693         5693
# 4   2012    6403    6403    6396     6403    6403         6401
# 5   2013    8880    8880    8870     8880    8880         8835
# 6   2014   10693   10693   10679    10693   10693        10693
# 7   2015   13387   13387   13383    13387   13387        13386
# 8   2016   18573   18573   18439    18573   18573        18573
# 9   2017   20945   20945   20656    20945   20945        20945
# 10  2018   28354   28354   28125    28354   28354        28354
# 11  2019   31002   31002   30597    31002   31002        31002
#
#     ResponsibleAgency  Category  RequestType  ...  \
# 1                5771      5771         5771  ...
# 2                5852      5852         5852  ...
# 3                5693      5693         5693  ...
# ...

# %%
decade = by_years[1:12]

# %%
import pandas as pd

# %%
decade.rename(columns={'Opened':'Cases'}, inplace = True) #renames the column to "Cases" since previously it was originally called "Open"
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
decade.head(12)
# Out:
#     year  CaseID  Cases  Closed  Updated  Status  StatusNotes  \
# 1   2009    5771   5771    5771     5771    5771         5769
# 2   2010    5852   5852    5852     5852    5852         5852
# 3   2011    5693   5693    5690     5693    5693         5693
# 4   2012    6403   6403    6396     6403    6403         6401
# 5   2013    8880   8880    8870     8880    8880         8835
# 6   2014   10693  10693   10679    10693   10693        10693
# 7   2015   13387  13387   13383    13387   13387        13386
# 8   2016   18573  18573   18439    18573   18573        18573
# 9   2017   20945  20945   20656    20945   20945        20945
# 10  2018   28354  28354   28125    28354   28354        28354
# 11  2019   31002  31002   30597    31002   31002        31002
#
#     ResponsibleAgency  Category  RequestType  ...  \
# 1                5771      5771         5771  ...
# 2                5852      5852         5852  ...
# 3                5693      5693         5693  ...
# ...

# %%
decade.rename(columns = {'year':'Year'}, inplace = True) #renames column name to year to Year
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
decade.head(12)
# Out:
#     Year  CaseID  Cases  Closed  Updated  Status  StatusNotes  \
# 1   2009    5771   5771    5771     5771    5771         5769
# 2   2010    5852   5852    5852     5852    5852         5852
# 3   2011    5693   5693    5690     5693    5693         5693
# 4   2012    6403   6403    6396     6403    6403         6401
# 5   2013    8880   8880    8870     8880    8880         8835
# 6   2014   10693  10693   10679    10693   10693        10693
# 7   2015   13387  13387   13383    13387   13387        13386
# 8   2016   18573  18573   18439    18573   18573        18573
# 9   2017   20945  20945   20656    20945   20945        20945
# 10  2018   28354  28354   28125    28354   28354        28354
# 11  2019   31002  31002   30597    31002   31002        31002
#
#     ResponsibleAgency  Category  RequestType  ...  \
# 1                5771      5771         5771  ...
# 2                5852      5852         5852  ...
# 3                5693      5693         5693  ...
# ...

# %%
decade.plot(kind = 'scatter', x='Year', y='Cases') #creates scatter plot of number cases as years pass by

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
Year = decade.iloc[:,0].values.reshape(-1,1) 
Cases = decade.iloc[:,1].values.reshape(-1,1)
linear_regressor = LinearRegression()
linear_regressor.fit(Year, Cases)
Cases_pred = linear_regressor.predict(Year) #shapes the line on the graph

# %%
plt.scatter(Year, Cases)
plt.plot(Year, Cases_pred, color='red')
plt.show()

# %%
plt.scatter(Year, Cases)
plt.plot (Year, Cases_pred, color = 'red')
plt.xlabel('Year')
plt.ylabel('Cases of Human or Animal Waste')
plt.title('Cases of Human or Animal Waste between 2009-2019') 
plt.show() #displays all the titles on the graph
