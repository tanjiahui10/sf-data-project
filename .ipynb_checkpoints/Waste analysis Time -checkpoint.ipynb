# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("~/Desktop/code/sf-data-project/data/processed/human_animal_waste_311.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of           CaseID                  Opened                  Closed  \
# 0       11872343  12/29/2019 09:52:00 AM  12/30/2019 04:10:00 PM
# 1       11931510  01/11/2020 04:12:00 PM  01/13/2020 04:04:00 PM
# 2       11872386  12/29/2019 10:06:00 AM  12/30/2019 07:56:00 PM
# 3       11872557  12/29/2019 10:52:41 AM  12/30/2019 07:46:00 AM
# 4       11872553  12/29/2019 10:51:53 AM  12/30/2019 09:50:00 AM
# ...          ...                     ...                     ...
# 161817  11440809  09/20/2019 07:49:53 AM  09/20/2019 10:51:00 AM
# 161818  11450185  09/22/2019 12:29:00 PM  09/23/2019 10:37:00 AM
# 161819  11453549  09/23/2019 10:30:00 AM  09/23/2019 11:01:00 AM
# 161820  11418365  09/15/2019 10:35:00 AM  09/15/2019 11:06:00 AM
# 161821  11453815  09/23/2019 11:03:00 AM  09/23/2019 12:53:00 PM
#
#                        Updated  Status                         StatusNotes  \
# 0       12/30/2019 04:10:00 PM  Closed                       Case Resolved
# ...

# %%
df.head()
# Out:
#      CaseID                  Opened                  Closed  \
# 0  11872343  12/29/2019 09:52:00 AM  12/30/2019 04:10:00 PM
# 1  11931510  01/11/2020 04:12:00 PM  01/13/2020 04:04:00 PM
# 2  11872386  12/29/2019 10:06:00 AM  12/30/2019 07:56:00 PM
# 3  11872557  12/29/2019 10:52:41 AM  12/30/2019 07:46:00 AM
# 4  11872553  12/29/2019 10:51:53 AM  12/30/2019 09:50:00 AM
#
#                   Updated  Status    StatusNotes ResponsibleAgency  \
# 0  12/30/2019 04:10:00 PM  Closed  Case Resolved     DPW Ops Queue
# 1  01/13/2020 04:04:00 PM  Closed  Case Resolved     DPW Ops Queue
# 2  12/30/2019 07:56:00 PM  Closed  Case Resolved     DPW Ops Queue
# 3  12/30/2019 07:46:00 AM  Closed  Case Resolved     DPW Ops Queue
# 4  12/30/2019 09:50:00 AM  Closed  Case Resolved     DPW Ops Queue
#
#                        Category            RequestType         RequestDetails  \
# 0  Street and Sidewalk Cleaning  Human or Animal Waste  Human or Animal Waste
# ...

# %%
pd.isnull(df).any()
# Out:
# CaseID                         False
# Opened                         False
# Closed                          True
# Updated                        False
# Status                         False
# StatusNotes                     True
# ResponsibleAgency              False
# Category                       False
# RequestType                    False
# RequestDetails                  True
# Address                        False
# Street                          True
# SupervisorDistrict              True
# Neighborhood                    True
# PoliceDistrict                  True
# Latitude                       False
# Longitude                      False
# Point                          False
# Source                         False
# MediaURL                        True
# SFFindNeighborhoods             True
# CurrentPoliceDistricts          True
# CurrentSupervisorDistricts      True
# AnalysisNeighborhoods           True
# :@computed_region_rxqg_mtj9     True
# ...

# %%
t = pd.tslib.Timestamp.now()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-49703b643488> in <module>
# ----> 1 t = pd.tslib.Timestamp.now()
#
# ~/.local/share/virtualenvs/sf-data-project-4Smp9qXc/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'tslib'

# %%
df['year'] = pd.DatetimeIndex(df['Opened']).year

# %%
df.head()
# Out:
#      CaseID                  Opened                  Closed  \
# 0  11872343  12/29/2019 09:52:00 AM  12/30/2019 04:10:00 PM
# 1  11931510  01/11/2020 04:12:00 PM  01/13/2020 04:04:00 PM
# 2  11872386  12/29/2019 10:06:00 AM  12/30/2019 07:56:00 PM
# 3  11872557  12/29/2019 10:52:41 AM  12/30/2019 07:46:00 AM
# 4  11872553  12/29/2019 10:51:53 AM  12/30/2019 09:50:00 AM
#
#                   Updated  Status    StatusNotes ResponsibleAgency  \
# 0  12/30/2019 04:10:00 PM  Closed  Case Resolved     DPW Ops Queue
# 1  01/13/2020 04:04:00 PM  Closed  Case Resolved     DPW Ops Queue
# 2  12/30/2019 07:56:00 PM  Closed  Case Resolved     DPW Ops Queue
# 3  12/30/2019 07:46:00 AM  Closed  Case Resolved     DPW Ops Queue
# 4  12/30/2019 09:50:00 AM  Closed  Case Resolved     DPW Ops Queue
#
#                        Category            RequestType         RequestDetails  \
# 0  Street and Sidewalk Cleaning  Human or Animal Waste  Human or Animal Waste
# ...

# %%
waste_by_years= df.groupby('year').count()

# %%
waste_by_years.sort_values('year').reset_index()
# Out:
#     year  CaseID  Opened  Closed  Updated  Status  StatusNotes  \
# 0   2008    1746    1746    1746     1746    1746         1741
# 1   2009    5771    5771    5771     5771    5771         5769
# 2   2010    5852    5852    5852     5852    5852         5852
# 3   2011    5693    5693    5690     5693    5693         5693
# 4   2012    6403    6403    6396     6403    6403         6401
# 5   2013    8880    8880    8870     8880    8880         8835
# 6   2014   10693   10693   10679    10693   10693        10693
# 7   2015   13387   13387   13383    13387   13387        13386
# 8   2016   18573   18573   18439    18573   18573        18573
# 9   2017   20945   20945   20655    20945   20945        20945
# 10  2018   28354   28354   28125    28354   28354        28354
# 11  2019   31002   31002   30597    31002   31002        31002
# 12  2020    4523    4523    4352     4523    4523         4523
#
#     ResponsibleAgency  Category  RequestType  ...  \
# ...

# %%
waste_by_years.plot(kind='scatter', x='year', y='Opened')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/sf-data-project-4Smp9qXc/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year '
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-bee4cb7df05b> in <module>
# ...

# %%
waste_by_years.years.Opened
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-50d0dcb72496> in <module>
# ----> 1 waste_by_years.years.Opened
#
# ~/.local/share/virtualenvs/sf-data-project-4Smp9qXc/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'years'

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import andrews_curves
df2 = pd.read_csv('iris.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-9143ce2c590c> in <module>
#       3 import matplotlib.pyplot as plt
#       4 from pandas.plotting import andrews_curves
# ----> 5 df2 = pd.read_csv('iris.csv')
#
# ...

# %%
waste_by_years= df.groupby('year').count()

# %%
waste_by_years.sort_values('year').reset_index()
# Out:
#     year  CaseID  Opened  Closed  Updated  Status  StatusNotes  \
# 0   2008    1746    1746    1746     1746    1746         1741
# 1   2009    5771    5771    5771     5771    5771         5769
# 2   2010    5852    5852    5852     5852    5852         5852
# 3   2011    5693    5693    5690     5693    5693         5693
# 4   2012    6403    6403    6396     6403    6403         6401
# 5   2013    8880    8880    8870     8880    8880         8835
# 6   2014   10693   10693   10679    10693   10693        10693
# 7   2015   13387   13387   13383    13387   13387        13386
# 8   2016   18573   18573   18439    18573   18573        18573
# 9   2017   20945   20945   20655    20945   20945        20945
# 10  2018   28354   28354   28125    28354   28354        28354
# 11  2019   31002   31002   30597    31002   31002        31002
# 12  2020    4523    4523    4352     4523    4523         4523
#
#     ResponsibleAgency  Category  RequestType  ...  \
# ...

# %%
by_years= waste_by_years.sort_values('year').reset_index()

# %%
by_years.head()
# Out:
#    year  CaseID  Opened  Closed  Updated  Status  StatusNotes  \
# 0  2008    1746    1746    1746     1746    1746         1741
# 1  2009    5771    5771    5771     5771    5771         5769
# 2  2010    5852    5852    5852     5852    5852         5852
# 3  2011    5693    5693    5690     5693    5693         5693
# 4  2012    6403    6403    6396     6403    6403         6401
#
#    ResponsibleAgency  Category  RequestType  ...  :@computed_region_fcz8_est8  \
# 0               1746      1746         1746  ...                          697
# 1               5771      5771         5771  ...                         2038
# 2               5852      5852         5852  ...                         2124
# 3               5693      5693         5693  ...                         2113
# 4               6403      6403         6403  ...                         2657
#
#    :@computed_region_pigm_ib2e  :@computed_region_9jxd_iqea  \
# ...

# %%
by_years.plot(kind='scatter', x='year', y='Opened')

# %%
by_years= waste_by_years.sort_values('year').reset_index()

# %%
by_years.head(12)
# Out:
#     year  CaseID  Opened  Closed  Updated  Status  StatusNotes  \
# 0   2008    1746    1746    1746     1746    1746         1741
# 1   2009    5771    5771    5771     5771    5771         5769
# 2   2010    5852    5852    5852     5852    5852         5852
# 3   2011    5693    5693    5690     5693    5693         5693
# 4   2012    6403    6403    6396     6403    6403         6401
# 5   2013    8880    8880    8870     8880    8880         8835
# 6   2014   10693   10693   10679    10693   10693        10693
# 7   2015   13387   13387   13383    13387   13387        13386
# 8   2016   18573   18573   18439    18573   18573        18573
# 9   2017   20945   20945   20655    20945   20945        20945
# 10  2018   28354   28354   28125    28354   28354        28354
# 11  2019   31002   31002   30597    31002   31002        31002
#
#     ResponsibleAgency  Category  RequestType  ...  \
# 0                1746      1746         1746  ...
# ...

# %%
by_years.head(13)
# Out:
#     year  CaseID  Opened  Closed  Updated  Status  StatusNotes  \
# 0   2008    1746    1746    1746     1746    1746         1741
# 1   2009    5771    5771    5771     5771    5771         5769
# 2   2010    5852    5852    5852     5852    5852         5852
# 3   2011    5693    5693    5690     5693    5693         5693
# 4   2012    6403    6403    6396     6403    6403         6401
# 5   2013    8880    8880    8870     8880    8880         8835
# 6   2014   10693   10693   10679    10693   10693        10693
# 7   2015   13387   13387   13383    13387   13387        13386
# 8   2016   18573   18573   18439    18573   18573        18573
# 9   2017   20945   20945   20655    20945   20945        20945
# 10  2018   28354   28354   28125    28354   28354        28354
# 11  2019   31002   31002   30597    31002   31002        31002
# 12  2020    4523    4523    4352     4523    4523         4523
#
#     ResponsibleAgency  Category  RequestType  ...  \
# ...

# %%
decade= by_years.drop([0,12], axis=0, inplace=True)
#????why isn't this working haha trying to delete the two rows 2008 and 2020 so as to get the decade of 2009 - 2019 for more accurate results.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-8f1e549c072b> in <module>
# ----> 1 decade= by_years.drop([0,12], axis=0, inplace=True)
#       2 #????why isn't this working haha trying to delete the two rows 2008 and 2020 so as to get the decade of 2009 - 2019 for more accurate results.
#
# ~/.local/share/virtualenvs/sf-data-project-4Smp9qXc/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/.local/share/virtualenvs/sf-data-project-4Smp9qXc/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
# ...
